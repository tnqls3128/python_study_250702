# %% [markdown]
# 21. 알라딘에서 '자기계발' 베스트 도서의 제목과 저자를 수집하세요.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())
options = Options()

options.add_argument('--disable-gpu')
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service = service, options=options)

url = "https://www.aladin.co.kr/shop/wbrowse.aspx?CID=38400&start=we_header"
driver.get(url)
time.sleep(3)

books = driver.find_elements(By.CSS_SELECTOR, "div.ss_book_list")

for book in books :
    titles = book.find_elements(By.CSS_SELECTOR, "a.bo3")
    authors = book.find_elements(By.CSS_SELECTOR, "a")
    for t in titles :
        print(t.text.strip())
    for a in authors :
        print(a.text.strip())
# Out:
# 미묘한 메모의 묘미
# 화제의 eBook + 북파우치
# 미묘한 메모의 묘미
# 김중혁
# 유유
# 6
# 종이책 보기
# 열심히 살아도 불안한 사람들
# 화제의 eBook + 북파우치
# 열심히 살아도 불안한 사람들
# 랄리타 수글라니
# 박선령
# 알에이치코리아(RHK)
# 21
# 종이책 보기
# 행동은 불안을 이긴다
# 화제의 eBook + 북파우치
# 행동은 불안을 이긴다
# 롭 다이얼
# 박영준
# 서삼독
# 17
# 종이책 보기
# 듀얼 브레인
# 화제의 eBook + 북파우치
# 듀얼 브레인
# 이선 몰릭
# 신동숙
# 상상스퀘어
# 31
# 종이책 보기
# 아티스트 웨이 : 30주년 기념 특별판
# 화제의 eBook + 북파우치
# 아티스트 웨이 : 30주년 기념 특별판
# 아티스트 웨이
# 줄리아 캐머런
# 박미경
# 위즈덤하우스
# 37
# 종이책 보기
# 데일 카네기 인간관계론
# 데일 카네기 인간관계론
# 데일 카네기 초판 완역본 시리즈
# 데일 카네기
# 임상훈
# 현대지성
# 182
# 첫 달 무료로 시작하기
# 종이책 보기
# 리얼리티 트랜서핑.
# 리얼리티 트랜서핑.
# 리얼리티 트랜서핑. 시리즈보기
# 박인수
# 정신세계사
# 19
# 종이책 보기
# 디바인 매트릭스, 느낌이 현실이 된다
# 디바인 매트릭스, 느낌이 현실이 된다
# 그렉 브레이든
# 김시현
# 김영사
# 13
# 종이책 보기
# 너를 미워할 시간에 나를 사랑하기로 했다
# 너를 미워할 시간에 나를 사랑하기로 했다
# 윤서진
# 스몰빅라이프
# 10
# 첫 달 무료로 시작하기
# 종이책 보기
# 무한의 부
# 무한의 부
# 왕징
# 김우성
# 필로틱
# 13
# 종이책 보기
# 나는 보았습니다
# 나는 보았습니다
# 박진여
# 김영사
# 12
# 종이책 보기
# 대화의 정석
# 대화의 정석
# 정흥수(흥버튼)
# FIKA(피카)
# 18
# 종이책 보기
# 한석준의 대화의 기술
# 한석준의 대화의 기술
# 한석준
# 인플루엔셜(주)
# 26
# 종이책 보기
# ...
