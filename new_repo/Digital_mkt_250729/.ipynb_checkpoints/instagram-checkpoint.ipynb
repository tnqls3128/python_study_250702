# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.instagram.com/accounts/login")
print("수동으로 인증 시작!")
time.sleep(30)

with open("instagram_cookies.pkl", "wb") as f :
    pickle.dump(driver.get_cookies(), f)

print("쿠키 저장 완료")
driver.quit()
# Out:
# 수동으로 인증 시작!
# 쿠키 저장 완료

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.instagram.com")

with open("instagram_cookies.pkl", "rb") as f :
    cookies = pickle.load(f)
for cookie in cookies :
    driver.add_cookie(cookie)

driver.refresh()
time.sleep(5)

try :
    not_now = driver.find_element(By.XPATH, "//button[text()='나중에 하기']")
    not_now.click()
    time.sleep(2)
except :
    pass

keyword = "여름패션"
driver.get(f"https://www.instagram.com/explore/tags/{keyword}")
time.sleep(5)

post_links = set()
for _ in range(3) :
    links = driver.find_elements(By.TAG_NAME, "a")
    for link in links :
        href = link.get_attribute("href")
        if href and "/p/" in href :
            post_links.add(href)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)

results = []
for url in list(post_links)[:10] :
    driver.get(url)
    time.sleep(3)
    caption = ""

    try : 
        img_tag = driver.find_element(By.XPATH, "//img[@alt]")
        caption = img_tag.get_attribute("alt").strip()
        results.append({"url" : url, "caption" : caption})

    except Exception as e :
        print(f"캡션 추출 실패 : {url} | 에러 : {e}")
        continue 
driver.quit()

for r in results :
    print(r["url"])
    print(r["caption"])
    print("="*60)
# Out:
# https://www.instagram.com/p/DLCnUhaPnld/
# Photo by w.Art magazine 더아트매거진 on June 18, 2025. 사람 1명, 잡지, 상의 및 문구: 'CultureFashion Culture Fashion 대충 걸쳐도 예쁘잖아요 나만 알고싶어.. ပူပဇပ いとん 이런 감성이 좋아 최애 아이템 추천 추천.zip zip w.Art Magazine'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/C-aPKzvP-Ls/
# #유나 #yuna #있지 #itzy #있지유나 #여름긴팔 #여름코디 #여름긴팔티 #여름가디건 #여름가디건추천 #여름패션 여름옷 10대 20대 패션 옷 아웃핏 룩 유나 코디 패션정보 연예인패션 긴팔추천 옷추천 여름옷 긴팔가디건 리넨 리넨가디건
# ============================================================
# https://www.instagram.com/p/DMm_eevp0w8/
# Photo by 크로켓 on July 27, 2025. ‎사람 1명 및 ‎문구: '‎크로켓 נהר 프류게에이 코로켓프램제에이셀러 프북 브러 croket ษ้ 냉방병 예방하기 딱좋은셔츠! 딱 좋은 셔츠! 실안티팀으로떡인! 폭로추천 데일 레일리시츠‎'‎‎의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DK86lzjxMtU/
# Photo by 오뭐입? on June 15, 2025. 사람 3명 및 문구: 'onl 주말에 입고 싶은 여름 데일리 코디 모음'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DLJYF-XSTDL/
# Photo by 패션매거진 on June 20, 2025. 사람 1명 및 문구: '힙녀가 되고싶은 되고 싶은 유교걸의 슬리브리스 유교걸에게 나시는 나시는"굉장한 굉장한 용기가 필요해 OnlyF.shionMagkzine Only Fashion Magazine'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DLU1ui-iIf2/
# Photo by IGOTSHE magazine 아가씨 매거진 on June 25, 2025. 사람 1명 및 문구: 'IGOTSHE MAGAZINE 나시 12개 있는데 또 사려고... 여름에 나시만 입는 에디터의 민소매 추천'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DKzGsOEps7A/
# Photo by BAOㅣ패션 & 라이프스타일 큐레이터 on June 12, 2025. 사람 1명, 머리카락 및 문구: 'BAO BAO|Fashion I Fashion an Tafanites blicites Fotografien Geschichten, ทลา Inspirationen Syamum (0 Synam und Gesprächen. 지금 안 사면 늦을걸 느낌 괜찮은 반팔티 6'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DMrnNqvzCUk/
# Photo by 디스패치 스타일 on July 28, 2025. 사람 1명, 야외 및 문구: '0 RESPASS LOTERNG BYLAIP 商机店 税菌 NIMDEN MDGUR CUFZ TAD000A SUE - 지수도 입은 알라딘 딘궁전가는바지 바지 궁전 가는 fashion DXICII'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DKTc8YRvBN9/
# Photo by 때깔 아카이브 on May 30, 2025. 사람 1명 및 문구: 'po ١ 이대로 입어볼래? 핀터레스트 코디북, zip 이것만 따라 하면 너도 핀터깔 소녀63 소녀 ttae_archive archive'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DKQtOLITU3-/
# Photo by 오마이선글라스 l OMYSUNGLASS on May 29, 2025. 사람 1명 이상, 머리카락 및 문구: 'FASHIONI FASHIONIOMYSUNGLAŚ OmY OMYSUNGLAS 여름 여름패션 패션 고민이라면 참고해 센스 있는 옷잘알 여자 연예인들로 보는 여름 스타일'의 이미지일 수 있음.
# ============================================================
