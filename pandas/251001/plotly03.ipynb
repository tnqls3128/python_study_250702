# %%
import pandas as pd
import plotly.graph_objects as go
import numpy as np

df = pd.DataFrame(np.random.rand(10,2), columns=["A", "B"])

fig = go.Figure()

fig.add_trace(
    go.Bar(
        x=df.index, y=df["A"], name="A", text=["A"], textposition="auto", texttemplate="%{y:.2f}"
    )
)

fig.add_trace(
    go.Bar(
        x=df.index, y=df["B"], name="B", text=["B"], textposition="auto", texttemplate="%{y:.2f}"
    )
)

fig.update_layout(
    {
        "title" : {
            "text" : "Graph with <b>go.Bar<b>",
            "x" : 0.5,
            "y" : 0.9,
            "font" : {
                "size" : 20
            }
        },
        "xaxis" : {
            "title": "random number",
            "showticklabels" : True,
            "dtick" : 1
        },
        "yaxis" : {
            "title" : "A"
        },
        "width" : 800,
        "height" : 340
    }
)

fig.show()

# %%
import numpy as np

test = np.random.rand(2, 2)
test

# pandas > Series(1차원 배열 데이터) / Datafrome(2차원 배열 데이터)
# Out:
# array([[0.19903478, 0.8066959 ],
#        [0.2304385 , 0.22294492]])
