# %%
import pandas as pd

df = pd.DataFrame({
    "미국" : [2.1, 2.2, 2.3],
    "한국" : [0.4, 0.5, 0.45],
    "중국" : [10, 13, 15],
})

df
# Out:
#     미국    한국  중국
# 0  2.1  0.40  10
# 1  2.2  0.50  13
# 2  2.3  0.45  15

# %%
import pandas as pd

df = pd.DataFrame({
    "미국" : [2.1, 2.2, 2.3],
    "한국" : [0.4, 0.5, 0.45],
    "중국" : [10, 13, 15],
}, index=[2000, 2010, 2020])

df
# Out:
#        미국    한국  중국
# 2000  2.1  0.40  10
# 2010  2.2  0.50  13
# 2020  2.3  0.45  15

# %%
df.index
# Out:
# Index([2000, 2010, 2020], dtype='int64')

# %%
df.index = [2001, 2002, 2003]

# %%
df
# Out:
#        미국    한국  중국
# 2001  2.1  0.40  10
# 2002  2.2  0.50  13
# 2003  2.3  0.45  15

# %%
df.columns = ["일본", "필리핀", "러시아"]
df
# Out:
#        일본   필리핀  러시아
# 2001  2.1  0.40   10
# 2002  2.2  0.50   13
# 2003  2.3  0.45   15

# %%
df.values
# Out:
# array([[ 2.1 ,  0.4 , 10.  ],
#        [ 2.2 ,  0.5 , 13.  ],
#        [ 2.3 ,  0.45, 15.  ]])

# %%
import pandas as pd

df = pd.DataFrame({
    "년도" : [2000, 2010, 2020],
    "미국" : [2.1, 2.2, 2.3],
    "한국" : [0.4, 0.5, 0.45],
    "중국" : [10, 13, 15],
}, index=[2000, 2010, 2020])

df
# Out:
#         년도   미국    한국  중국
# 2000  2000  2.1  0.40  10
# 2010  2010  2.2  0.50  13
# 2020  2020  2.3  0.45  15

# %%
df = df.set_index("년도")
df
# Out:
#        미국    한국  중국
# 년도
# 2000  2.1  0.40  10
# 2010  2.2  0.50  13
# 2020  2.3  0.45  15

# %%
df.index.name = "연도"

# %%
df.index.name
# Out:
# '연도'

# %%
df = df.reset_index("연도")
df
# Out:
#      연도   미국    한국  중국
# 0  2000  2.1  0.40  10
# 1  2010  2.2  0.50  13
# 2  2020  2.3  0.45  15

# %%
df = df.set_index("연도")
df
# Out:
#        미국    한국  중국
# 연도
# 2000  2.1  0.40  10
# 2010  2.2  0.50  13
# 2020  2.3  0.45  15

# %%
df.loc[2000]
# Out:
# 미국     2.1
# 한국     0.4
# 중국    10.0
# Name: 2000, dtype: float64

# %%
df.iloc[0]  # 인덱스 이름이 아닌 인덱스의 연번=순번을 기준으로 record의 값을 찾아올 떄 사용
# Out:
# 미국     2.1
# 한국     0.4
# 중국    10.0
# Name: 2000, dtype: float64

# %%
type(df.loc[2000])
# Out:
# pandas.core.series.Series

# %%
df["미국"]
# Out:
# 연도
# 2000    2.1
# 2010    2.2
# 2020    2.3
# Name: 미국, dtype: float64

# %%
type(df["미국"])
# Out:
# pandas.core.series.Series

# %%
print(df["미국"][2010])
# Out:
# 2.2

# %%
print(df.loc[2010]["미국"])
# Out:
# 2.2

# %%
import pandas as pd

df = pd.DataFrame({
    "년도" : ["2000", "2010", "2020"],
    "미국" : [2.1, 2.2, 2.3],
    "한국" : [0.4, 0.5, 0.45],
    "중국" : [10, 13, 15],
}, index=[2000, 2010, 2020])

df
# Out:
#         년도   미국    한국  중국
# 2000  2000  2.1  0.40  10
# 2010  2010  2.2  0.50  13
# 2020  2020  2.3  0.45  15

# %%
df = df.set_index("년도")
df
# Out:
#        미국    한국  중국
# 년도
# 2000  2.1  0.40  10
# 2010  2.2  0.50  13
# 2020  2.3  0.45  15

# %%
df.index
# Out:
# Index(['2000', '2010', '2020'], dtype='object', name='년도')

# %%
df.loc["2000"]
# Out:
# 미국     2.1
# 한국     0.4
# 중국    10.0
# Name: 2000, dtype: float64

# %%
df["미국"]
# Out:
# 년도
# 2000    2.1
# 2010    2.2
# 2020    2.3
# Name: 미국, dtype: float64

# %%
df["일본"] = [1, 2, 3]
df
# Out:
#        미국    한국  중국  일본
# 년도
# 2000  2.1  0.40  10   1
# 2010  2.2  0.50  13   2
# 2020  2.3  0.45  15   3

# %%
del df["일본"]
df
# Out:
#        미국    한국  중국
# 년도
# 2000  2.1  0.40  10
# 2010  2.2  0.50  13
# 2020  2.3  0.45  15

# %%
df.loc[2021] = [1, 2, 3]
df
# Out:
#        미국    한국  중국
# 년도
# 2000  2.1  0.40  10
# 2010  2.2  0.50  13
# 2020  2.3  0.45  15
# 2021  1.0  2.00   3

# %%
df.drop([2021])
df
# Out:
#        미국    한국  중국
# 년도
# 2000  2.1  0.40  10
# 2010  2.2  0.50  13
# 2020  2.3  0.45  15
# 2021  1.0  2.00   3

# %%
df.drop(["2020"])
# Out:
#        미국   한국  중국
# 년도
# 2000  2.1  0.4  10
# 2010  2.2  0.5  13
# 2021  1.0  2.0   3

# %%
df
# Out:
#        미국    한국  중국
# 년도
# 2000  2.1  0.40  10
# 2010  2.2  0.50  13
# 2020  2.3  0.45  15
# 2021  1.0  2.00   3

# %%
df.drop(["2020"], inplace=True)  # drop => 임시삭제

# %%
df
# Out:
#        미국   한국  중국
# 년도
# 2000  2.1  0.4  10
# 2010  2.2  0.5  13
# 2021  1.0  2.0   3

# %%
df2 = df[["중국", "한국"]].copy()  # 날리지않고 이렇게 값 가져오기
df2
# Out:
#       중국   한국
# 년도
# 2000  10  0.4
# 2010  13  0.5
# 2021   3  2.0

# %%
df2.columns = ["브라질", "아르헨티나"]
df2
# Out:
#       브라질  아르헨티나
# 년도
# 2000   10    0.4
# 2010   13    0.5
# 2021    3    2.0

# %%
df
# Out:
#        미국   한국  중국
# 년도
# 2000  2.1  0.4  10
# 2010  2.2  0.5  13
# 2021  1.0  2.0   3
