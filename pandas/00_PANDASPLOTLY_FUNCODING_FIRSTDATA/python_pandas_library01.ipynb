# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

seriesData = pd.Series([70, 60, 90])
seriesData
# Out:
# 0    70
# 1    60
# 2    90
# dtype: int64

# %%
import pandas as pd

df = pd.DataFrame({
    "미국" : [2.1, 2.2, 2.3],
    "한국" : [0.4, 0.5, 0.45],
    "중국" : [10, 13, 15],
})

df
# Out:
#     미국    한국  중국
# 0  2.1  0.40  10
# 1  2.2  0.50  13
# 2  2.3  0.45  15

# %%
import pandas as pd

seriesData = pd.Series([70, 60, 90], index=["국어", "영어", "수학"])
seriesData
# Out:
# 국어    70
# 영어    60
# 수학    90
# dtype: int64

# %%
seriesData.index
# Out:
# Index(['국어', '영어', '수학'], dtype='object')

# %%
seriesData.index = ["미술", "음악", "체육"]

# %%
seriesData
# Out:
# 미술    70
# 음악    60
# 체육    90
# dtype: int64

# %%
seriesData.values
# Out:
# array([70, 60, 90])

# %%
print(seriesData["미술"], seriesData.iloc[0])
print(seriesData["음악"], seriesData.iloc[1])
# Out:
# 70 70
# 60 60

# %%
seriesData["미술"] = 80  # 재할당

# %%
print(seriesData["미술"], seriesData.iloc[0])
# Out:
# 80 80

# %%
del seriesData["미술"]
seriesData
# Out:
# 음악    60
# 체육    90
# dtype: int64

# %%
seriesData02 = pd.Series(["Dave", "David", "Alex"])
seriesData02
# Out:
# 0     Dave
# 1    David
# 2     Alex
# dtype: object

# %%
seriesData03 = pd.Series(["Dave", "David", "Alex", 7])
seriesData03
# Out:
# 0     Dave
# 1    David
# 2     Alex
# 3        7
# dtype: object

# %%
seriesData04 = pd.Series([1, 1, 1])
seriesData04
# Out:
# 0    1
# 1    1
# 2    1
# dtype: int64

# %%
seriesData04.astype("float")
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# dtype: float64

# %%
seriesData05 = pd.Series([True, False, True])
seriesData05
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
seriesData06 = pd.Series(["David", 1, 2])
seriesData06
# Out:
# 0    David
# 1        1
# 2        2
# dtype: object

# %%
seriesData06.astype("float")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 seriesData06.astype("float")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
# ...
