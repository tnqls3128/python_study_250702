# %%
# 250911

data_file = open("00_data/text_data.txt", "r", encoding="utf-8-sig")
data_file.close()

# %%
with open("00_data/text_data.txt", "r", encoding="utf-8-sig") as data_file :
    data_lines = data_file.readlines()
    print(data_lines)
# Out:
# ['안녕하세요. Dave Lee 입니다.\n', '본 예제는 Plain Text 파일 예제입니다.\n', '감사합니다.']

# %%
data_file = open("00_data/text_data.txt", "r", encoding="utf-8-sig")
data_lines = data_file.readlines()
data_lines  # 실습 시에는 짧기때문에 with절 사용X
# Out:
# ['안녕하세요. Dave Lee 입니다.\n', '본 예제는 Plain Text 파일 예제입니다.\n', '감사합니다.']

# %%
for data_line in data_lines :
    print(data_line)
data_file.close()
# Out:
# 안녕하세요. Dave Lee 입니다.
#
# 본 예제는 Plain Text 파일 예제입니다.
#
# 감사합니다.

# %%
data_file = open("00_data/text_data.txt", "r", encoding="utf-8-sig")
data_line = data_file.readline()
print(data_line)
# Out:
# 안녕하세요. Dave Lee 입니다.

# %%
data_line = data_file.readline()
print(data_line)
# Out:
# 본 예제는 Plain Text 파일 예제입니다.

# %%
data_line = data_file.readline()
print(data_line)
# Out:
# 감사합니다.

# %%
data_line = data_file.readline()
print(data_line)

# %%
data_file = open("00_data/text_data.txt", "r", encoding="utf-8-sig")
data = data_file.read()  # list로 가져올 때 => readline(독립적인형태에서 바꿀 때)
data
# Out:
# '안녕하세요. Dave Lee 입니다.\n본 예제는 Plain Text 파일 예제입니다.\n감사합니다.'
