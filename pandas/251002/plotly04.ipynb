# %% [markdown]
# - 보다 세부적으로 EDA를 활용해서 데이터를 확인 및 검증하기 위한 방법론
# - feature = column 상관관계 분석
# - 데.사 & 데.분 -> 데이터 내 feature 간 상관관계를 누가 더 세부적이고 심도있게 밝혀내는가
# - heatmap 그래프
# - scatter 그래프
# - 상관관계를 체크 및 확인하기 위해서 상관계수
# - 상관계수 : 1에 수렴할수록 상관관계가 높다 / 0에 수렴할수록 상관관계가 낮다
